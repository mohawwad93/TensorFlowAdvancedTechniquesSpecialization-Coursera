# %% [markdown]
# This lab will show how you can define custom layers with the Lambda layer. You can either use lambda functions within the Lambda layer or define a custom function that the Lambda layer will call. Let's get started!

# %%
try:
  # %tensorflow_version 2.x
except:
  pass

import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255.0, x_test/255.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                    tf.keras.layers.Dense(units=128, activation='relu'),
                                    tf.keras.layers.Dense(units=10, activation='softmax')
                                    ])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4329 - accuracy: 0.8789
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1203 - accuracy: 0.9640
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0796 - accuracy: 0.9767
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0560 - accuracy: 0.9823
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0430 - accuracy: 0.9869
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0757 - accuracy: 0.9776
# [0.07570481300354004, 0.9775999784469604]

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                    tf.keras.layers.Dense(units=128),
                                    tf.keras.layers.Lambda(lambda x: tf.abs(x)),
                                    tf.keras.layers.Dense(units=10, activation='softmax')
                                    ])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3919 - accuracy: 0.8914
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0950 - accuracy: 0.9723
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0623 - accuracy: 0.9810
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0474 - accuracy: 0.9848
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0337 - accuracy: 0.9895
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9721
# [0.09428075700998306, 0.972100019454956]

# %%
def custom_relu(x):
  return tf.maximum(0.5, x)

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                    tf.keras.layers.Dense(units=128),
                                    tf.keras.layers.Lambda(custom_relu),
                                    tf.keras.layers.Dense(units=10, activation='softmax')
                                    ])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5271 - accuracy: 0.8510
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1387 - accuracy: 0.9596
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0924 - accuracy: 0.9734
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0714 - accuracy: 0.9784
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0564 - accuracy: 0.9839
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0762 - accuracy: 0.9779
# [0.07618395984172821, 0.9779000282287598]
